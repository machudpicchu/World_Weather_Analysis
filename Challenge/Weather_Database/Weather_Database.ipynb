# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | guerrero negro
# Processing Record 4 of Set 1 | jabinyanah
# Processing Record 5 of Set 1 | vasilkovo
# City not found. Skipping...
# Processing Record 6 of Set 1 | juan lacaze
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | marawi
# Processing Record 10 of Set 1 | tahta
# Processing Record 11 of Set 1 | samarai
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | faanui
# Processing Record 14 of Set 1 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 1 | berlevag
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | terrasini
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | catuday
# Processing Record 22 of Set 1 | avera
# Processing Record 23 of Set 1 | bathsheba
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | iskateley
# Processing Record 26 of Set 1 | yerazgavors
# Processing Record 27 of Set 1 | mackay
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | russell
# Processing Record 33 of Set 1 | haines junction
# Processing Record 34 of Set 1 | kolokani
# Processing Record 35 of Set 1 | kangaatsiaq
# Processing Record 36 of Set 1 | oksfjord
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | chifeng
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | raga
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | belaya gora
# Processing Record 49 of Set 1 | quesnel
# Processing Record 50 of Set 1 | sagaing
# Processing Record 1 of Set 2 | port-gentil
# Processing Record 2 of Set 2 | shache
# Processing Record 3 of Set 2 | lauro muller
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | marshfield
# Processing Record 7 of Set 2 | lima
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | andenes
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | lompoc
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | tyumentsevo
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | dera bugti
# Processing Record 18 of Set 2 | nago
# Processing Record 19 of Set 2 | roebourne
# Processing Record 20 of Set 2 | upernavik
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | santa flavia
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | milkovo
# Processing Record 26 of Set 2 | ushtobe
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | kahului
# Processing Record 29 of Set 2 | margate
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | karratha
# Processing Record 32 of Set 2 | iquitos
# Processing Record 33 of Set 2 | nioro
# Processing Record 34 of Set 2 | arman
# Processing Record 35 of Set 2 | ancud
# Processing Record 36 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 37 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 2 | kuytun
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | grindavik
# Processing Record 42 of Set 2 | vila velha
# Processing Record 43 of Set 2 | shimoda
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | tilichiki
# Processing Record 46 of Set 2 | sola
# Processing Record 47 of Set 2 | lidkoping
# Processing Record 48 of Set 2 | orsha
# Processing Record 49 of Set 2 | adrar
# Processing Record 50 of Set 2 | sungaipenuh
# Processing Record 1 of Set 3 | qandala
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | poum
# Processing Record 4 of Set 3 | aklavik
# Processing Record 5 of Set 3 | kunstat
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | ust-kuyga
# Processing Record 8 of Set 3 | boa vista
# Processing Record 9 of Set 3 | itoman
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | lata
# Processing Record 13 of Set 3 | gejiu
# Processing Record 14 of Set 3 | portland
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | wanaka
# Processing Record 18 of Set 3 | xining
# Processing Record 19 of Set 3 | caravelas
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | saldanha
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | maarianhamina
# Processing Record 26 of Set 3 | karasuk
# Processing Record 27 of Set 3 | bereda
# Processing Record 28 of Set 3 | la asuncion
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | harnosand
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | vila
# Processing Record 33 of Set 3 | saint-pierre
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | pemangkat
# Processing Record 36 of Set 3 | ossora
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | santa vitoria do palmar
# Processing Record 39 of Set 3 | le port
# Processing Record 40 of Set 3 | ushuaia
# Processing Record 41 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 42 of Set 3 | puntarenas
# Processing Record 43 of Set 3 | flinders
# Processing Record 44 of Set 3 | mujiayingzi
# Processing Record 45 of Set 3 | evensk
# Processing Record 46 of Set 3 | tigil
# Processing Record 47 of Set 3 | pathein
# Processing Record 48 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 3 | tiksi
# Processing Record 50 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 4 | colares
# Processing Record 2 of Set 4 | canutama
# Processing Record 3 of Set 4 | vila franca do campo
# Processing Record 4 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | tucupita
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | saint-augustin
# Processing Record 9 of Set 4 | hamilton
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | jumla
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | tselinnoye
# Processing Record 14 of Set 4 | alta floresta
# Processing Record 15 of Set 4 | usinsk
# Processing Record 16 of Set 4 | sisimiut
# Processing Record 17 of Set 4 | vaini
# Processing Record 18 of Set 4 | mitsamiouli
# Processing Record 19 of Set 4 | santa ana
# Processing Record 20 of Set 4 | narwar
# Processing Record 21 of Set 4 | laguna
# Processing Record 22 of Set 4 | doha
# Processing Record 23 of Set 4 | bosaso
# Processing Record 24 of Set 4 | umm lajj
# Processing Record 25 of Set 4 | honningsvag
# Processing Record 26 of Set 4 | invermere
# Processing Record 27 of Set 4 | suclayin
# Processing Record 28 of Set 4 | hithadhoo
# Processing Record 29 of Set 4 | camacha
# Processing Record 30 of Set 4 | worthing
# Processing Record 31 of Set 4 | baracoa
# Processing Record 32 of Set 4 | noshiro
# Processing Record 33 of Set 4 | la rioja
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | narsaq
# Processing Record 36 of Set 4 | estevan
# Processing Record 37 of Set 4 | vostok
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | mahebourg
# Processing Record 40 of Set 4 | broken hill
# Processing Record 41 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 4 | lavrentiya
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | zalantun
# Processing Record 45 of Set 4 | isabela
# Processing Record 46 of Set 4 | sept-iles
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | bugojno
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | pachmarhi
# Processing Record 1 of Set 5 | tasiilaq
# Processing Record 2 of Set 5 | belmonte
# Processing Record 3 of Set 5 | kaeo
# Processing Record 4 of Set 5 | borama
# City not found. Skipping...
# Processing Record 5 of Set 5 | ngorongoro
# Processing Record 6 of Set 5 | calafell
# Processing Record 7 of Set 5 | pecos
# Processing Record 8 of Set 5 | egvekinot
# Processing Record 9 of Set 5 | henties bay
# Processing Record 10 of Set 5 | palora
# Processing Record 11 of Set 5 | castro
# Processing Record 12 of Set 5 | husavik
# Processing Record 13 of Set 5 | broome
# Processing Record 14 of Set 5 | arraial do cabo
# Processing Record 15 of Set 5 | calama
# Processing Record 16 of Set 5 | anadyr
# Processing Record 17 of Set 5 | zyryanka
# Processing Record 18 of Set 5 | alofi
# Processing Record 19 of Set 5 | pevek
# Processing Record 20 of Set 5 | kabalo
# Processing Record 21 of Set 5 | niamey
# Processing Record 22 of Set 5 | livingston
# Processing Record 23 of Set 5 | muzaffarabad
# Processing Record 24 of Set 5 | namatanai
# Processing Record 25 of Set 5 | ponta do sol
# Processing Record 26 of Set 5 | luderitz
# Processing Record 27 of Set 5 | tecoanapa
# Processing Record 28 of Set 5 | lasa
# Processing Record 29 of Set 5 | ixtapa
# Processing Record 30 of Set 5 | hoquiam
# Processing Record 31 of Set 5 | la ronge
# Processing Record 32 of Set 5 | yellowknife
# Processing Record 33 of Set 5 | hokitika
# Processing Record 34 of Set 5 | carnarvon
# Processing Record 35 of Set 5 | oistins
# Processing Record 36 of Set 5 | quatre cocos
# Processing Record 37 of Set 5 | birecik
# Processing Record 38 of Set 5 | ararangua
# Processing Record 39 of Set 5 | novyy nekouz
# Processing Record 40 of Set 5 | phumi samraong
# City not found. Skipping...
# Processing Record 41 of Set 5 | turukhansk
# Processing Record 42 of Set 5 | codrington
# Processing Record 43 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 5 | okhotsk
# Processing Record 46 of Set 5 | kharp
# Processing Record 47 of Set 5 | erenhot
# Processing Record 48 of Set 5 | wailuku
# Processing Record 49 of Set 5 | malakal
# Processing Record 50 of Set 5 | temirtau
# Processing Record 1 of Set 6 | aleksandrov gay
# Processing Record 2 of Set 6 | tazovskiy
# Processing Record 3 of Set 6 | east london
# Processing Record 4 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 5 of Set 6 | kaoma
# Processing Record 6 of Set 6 | longyearbyen
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | severo-kurilsk
# Processing Record 9 of Set 6 | kadhan
# Processing Record 10 of Set 6 | dauriya
# Processing Record 11 of Set 6 | moindou
# Processing Record 12 of Set 6 | matamoros
# Processing Record 13 of Set 6 | lekoni
# Processing Record 14 of Set 6 | zhangye
# Processing Record 15 of Set 6 | labuhan
# Processing Record 16 of Set 6 | urucara
# Processing Record 17 of Set 6 | valdivia
# Processing Record 18 of Set 6 | nemuro
# Processing Record 19 of Set 6 | wewak
# Processing Record 20 of Set 6 | walvis bay
# Processing Record 21 of Set 6 | poso
# Processing Record 22 of Set 6 | richards bay
# Processing Record 23 of Set 6 | vanimo
# Processing Record 24 of Set 6 | yenagoa
# Processing Record 25 of Set 6 | lamont
# Processing Record 26 of Set 6 | bilibino
# Processing Record 27 of Set 6 | haukipudas
# Processing Record 28 of Set 6 | esperance
# Processing Record 29 of Set 6 | axim
# Processing Record 30 of Set 6 | tarko-sale
# Processing Record 31 of Set 6 | kerouane
# Processing Record 32 of Set 6 | kesennuma
# City not found. Skipping...
# Processing Record 33 of Set 6 | geraldton
# Processing Record 34 of Set 6 | krasnoye
# Processing Record 35 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 6 | cardoso
# Processing Record 37 of Set 6 | igrim
# Processing Record 38 of Set 6 | port keats
# Processing Record 39 of Set 6 | fortuna
# Processing Record 40 of Set 6 | coahuayana
# Processing Record 41 of Set 6 | huilong
# Processing Record 42 of Set 6 | malibu
# Processing Record 43 of Set 6 | syracuse
# Processing Record 44 of Set 6 | southbridge
# Processing Record 45 of Set 6 | huangchuan
# Processing Record 46 of Set 6 | bakchar
# Processing Record 47 of Set 6 | dudinka
# Processing Record 48 of Set 6 | chancay
# Processing Record 49 of Set 6 | zabaykalsk
# Processing Record 50 of Set 6 | kruisfontein
# Processing Record 1 of Set 7 | kushima
# Processing Record 2 of Set 7 | mbaiki
# Processing Record 3 of Set 7 | churapcha
# Processing Record 4 of Set 7 | kualakapuas
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | hami
# Processing Record 7 of Set 7 | mayo
# Processing Record 8 of Set 7 | vertientes
# Processing Record 9 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 7 | adre
# Processing Record 11 of Set 7 | provideniya
# Processing Record 12 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 7 | cumana
# Processing Record 14 of Set 7 | clyde river
# Processing Record 15 of Set 7 | sesimbra
# Processing Record 16 of Set 7 | choya
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | weligama
# Processing Record 19 of Set 7 | camocim
# Processing Record 20 of Set 7 | fairbanks
# Processing Record 21 of Set 7 | abyek
# Processing Record 22 of Set 7 | aquiraz
# Processing Record 23 of Set 7 | loandjili
# Processing Record 24 of Set 7 | valparaiso
# Processing Record 25 of Set 7 | uyuni
# Processing Record 26 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 7 | kathu
# Processing Record 28 of Set 7 | curvelo
# Processing Record 29 of Set 7 | omsukchan
# Processing Record 30 of Set 7 | los llanos de aridane
# Processing Record 31 of Set 7 | bermeo
# Processing Record 32 of Set 7 | bilma
# Processing Record 33 of Set 7 | bethel
# Processing Record 34 of Set 7 | richmond
# Processing Record 35 of Set 7 | barra do corda
# Processing Record 36 of Set 7 | finschhafen
# Processing Record 37 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 38 of Set 7 | misratah
# Processing Record 39 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 7 | buchanan
# Processing Record 41 of Set 7 | tarakan
# Processing Record 42 of Set 7 | pacific grove
# Processing Record 43 of Set 7 | sidi bu zayd
# City not found. Skipping...
# Processing Record 44 of Set 7 | lagoa
# Processing Record 45 of Set 7 | malangwa
# Processing Record 46 of Set 7 | kaitangata
# Processing Record 47 of Set 7 | bonavista
# Processing Record 48 of Set 7 | luanda
# Processing Record 49 of Set 7 | inuvik
# Processing Record 50 of Set 7 | kodinsk
# Processing Record 1 of Set 8 | kawalu
# Processing Record 2 of Set 8 | lalin
# Processing Record 3 of Set 8 | maues
# Processing Record 4 of Set 8 | bure
# Processing Record 5 of Set 8 | maine-soroa
# Processing Record 6 of Set 8 | hofn
# Processing Record 7 of Set 8 | maumere
# Processing Record 8 of Set 8 | marzuq
# Processing Record 9 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 8 | qaqortoq
# Processing Record 13 of Set 8 | shelby
# Processing Record 14 of Set 8 | sobolevo
# Processing Record 15 of Set 8 | makat
# Processing Record 16 of Set 8 | batemans bay
# Processing Record 17 of Set 8 | naze
# Processing Record 18 of Set 8 | huichapan
# Processing Record 19 of Set 8 | yar-sale
# Processing Record 20 of Set 8 | nishihara
# Processing Record 21 of Set 8 | simpang
# Processing Record 22 of Set 8 | corum
# Processing Record 23 of Set 8 | arroio grande
# Processing Record 24 of Set 8 | chara
# Processing Record 25 of Set 8 | dicabisagan
# Processing Record 26 of Set 8 | banjar
# Processing Record 27 of Set 8 | bengkulu
# Processing Record 28 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 8 | honiara
# Processing Record 30 of Set 8 | miraflores
# Processing Record 31 of Set 8 | booue
# Processing Record 32 of Set 8 | phayao
# Processing Record 33 of Set 8 | thinadhoo
# Processing Record 34 of Set 8 | miranda
# Processing Record 35 of Set 8 | klaksvik
# Processing Record 36 of Set 8 | pierre
# Processing Record 37 of Set 8 | knysna
# Processing Record 38 of Set 8 | nhulunbuy
# Processing Record 39 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 8 | zhigansk
# Processing Record 41 of Set 8 | port shepstone
# Processing Record 42 of Set 8 | novaya ladoga
# Processing Record 43 of Set 8 | half moon bay
# Processing Record 44 of Set 8 | gumushane
# City not found. Skipping...
# Processing Record 45 of Set 8 | manicore
# Processing Record 46 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 48 of Set 8 | harper
# Processing Record 49 of Set 8 | toyooka
# Processing Record 50 of Set 8 | minatitlan
# Processing Record 1 of Set 9 | sovetskiy
# Processing Record 2 of Set 9 | inhambane
# Processing Record 3 of Set 9 | port hardy
# Processing Record 4 of Set 9 | qui nhon
# Processing Record 5 of Set 9 | sayalgudi
# City not found. Skipping...
# Processing Record 6 of Set 9 | chirgaon
# Processing Record 7 of Set 9 | sur
# Processing Record 8 of Set 9 | stamsund
# City not found. Skipping...
# Processing Record 9 of Set 9 | samana
# Processing Record 10 of Set 9 | ust-omchug
# Processing Record 11 of Set 9 | alakurtti
# Processing Record 12 of Set 9 | barentu
# Processing Record 13 of Set 9 | redmond
# Processing Record 14 of Set 9 | olkhovka
# Processing Record 15 of Set 9 | kleck
# City not found. Skipping...
# Processing Record 16 of Set 9 | salinopolis
# Processing Record 17 of Set 9 | sinnamary
# Processing Record 18 of Set 9 | kamenka
# Processing Record 19 of Set 9 | hobyo
# Processing Record 20 of Set 9 | boke
# Processing Record 21 of Set 9 | sohag
# Processing Record 22 of Set 9 | parabel
# Processing Record 23 of Set 9 | vestmannaeyjar
# Processing Record 24 of Set 9 | touros
# Processing Record 25 of Set 9 | sistranda
# Processing Record 26 of Set 9 | boyolangu
# Processing Record 27 of Set 9 | fukue
# Processing Record 28 of Set 9 | neiafu
# Processing Record 29 of Set 9 | damortis
# Processing Record 30 of Set 9 | shahr-e babak
# Processing Record 31 of Set 9 | san quintin
# Processing Record 32 of Set 9 | marsabit
# Processing Record 33 of Set 9 | sisian
# Processing Record 34 of Set 9 | limulunga
# Processing Record 35 of Set 9 | metro
# Processing Record 36 of Set 9 | lorengau
# Processing Record 37 of Set 9 | roma
# Processing Record 38 of Set 9 | padang
# Processing Record 39 of Set 9 | isla vista
# Processing Record 40 of Set 9 | nome
# Processing Record 41 of Set 9 | mangaratiba
# Processing Record 42 of Set 9 | ifanadiana
# Processing Record 43 of Set 9 | aripuana
# Processing Record 44 of Set 9 | dingle
# Processing Record 45 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 9 | maracana
# Processing Record 47 of Set 9 | ilhabela
# Processing Record 48 of Set 9 | porto velho
# Processing Record 49 of Set 9 | hays
# Processing Record 50 of Set 9 | atyrau
# Processing Record 1 of Set 10 | leshukonskoye
# Processing Record 2 of Set 10 | la serena
# Processing Record 3 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 10 | sumenep
# Processing Record 5 of Set 10 | hoima
# Processing Record 6 of Set 10 | san juan
# Processing Record 7 of Set 10 | apsheronsk
# Processing Record 8 of Set 10 | akcakoca
# Processing Record 9 of Set 10 | mount gambier
# Processing Record 10 of Set 10 | leh
# Processing Record 11 of Set 10 | rio grande
# Processing Record 12 of Set 10 | havre-saint-pierre
# Processing Record 13 of Set 10 | taganak
# Processing Record 14 of Set 10 | guanica
# Processing Record 15 of Set 10 | stolin
# Processing Record 16 of Set 10 | asau
# Processing Record 17 of Set 10 | cabedelo
# Processing Record 18 of Set 10 | antofagasta
# Processing Record 19 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 20 of Set 10 | cidreira
# Processing Record 21 of Set 10 | ishigaki
# Processing Record 22 of Set 10 | grand-santi
# Processing Record 23 of Set 10 | tekeli
# Processing Record 24 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 10 | penzance
# Processing Record 26 of Set 10 | olafsvik
# Processing Record 27 of Set 10 | batagay
# Processing Record 28 of Set 10 | hanyang
# Processing Record 29 of Set 10 | meulaboh
# Processing Record 30 of Set 10 | kananga
# Processing Record 31 of Set 10 | wisconsin rapids
# Processing Record 32 of Set 10 | praia da vitoria
# Processing Record 33 of Set 10 | hellvik
# Processing Record 34 of Set 10 | sosnovo-ozerskoye
# Processing Record 35 of Set 10 | duzce
# Processing Record 36 of Set 10 | north platte
# Processing Record 37 of Set 10 | pangnirtung
# Processing Record 38 of Set 10 | johnston
# Processing Record 39 of Set 10 | havoysund
# Processing Record 40 of Set 10 | wilmington
# Processing Record 41 of Set 10 | deputatskiy
# Processing Record 42 of Set 10 | bonthe
# Processing Record 43 of Set 10 | odda
# Processing Record 44 of Set 10 | batote
# Processing Record 45 of Set 10 | villa bruzual
# Processing Record 46 of Set 10 | college
# Processing Record 47 of Set 10 | nata
# Processing Record 48 of Set 10 | warren
# Processing Record 49 of Set 10 | dehloran
# Processing Record 50 of Set 10 | trat
# Processing Record 1 of Set 11 | aden
# Processing Record 2 of Set 11 | barranca
# Processing Record 3 of Set 11 | alice springs
# Processing Record 4 of Set 11 | bayangol
# Processing Record 5 of Set 11 | talnakh
# Processing Record 6 of Set 11 | saint-leu
# Processing Record 7 of Set 11 | rio cuarto
# Processing Record 8 of Set 11 | coihaique
# Processing Record 9 of Set 11 | baykit
# Processing Record 10 of Set 11 | aktanysh
# Processing Record 11 of Set 11 | bayji
# Processing Record 12 of Set 11 | souillac
# Processing Record 13 of Set 11 | moose factory
# Processing Record 14 of Set 11 | paamiut
# Processing Record 15 of Set 11 | tobolsk
# Processing Record 16 of Set 11 | polunochnoye
# Processing Record 17 of Set 11 | kieta
# Processing Record 18 of Set 11 | jonuta
# Processing Record 19 of Set 11 | halifax
# Processing Record 20 of Set 11 | mandalgovi
# Processing Record 21 of Set 11 | bintulu
# Processing Record 22 of Set 11 | skelleftea
# Processing Record 23 of Set 11 | pandan niog
# Processing Record 24 of Set 11 | harrison
# Processing Record 25 of Set 11 | alekseyevsk
# Processing Record 26 of Set 11 | palmer
# Processing Record 27 of Set 11 | tautira
# Processing Record 28 of Set 11 | campobello di mazara
# Processing Record 29 of Set 11 | mushie
# Processing Record 30 of Set 11 | umm kaddadah
# Processing Record 31 of Set 11 | vung tau
# Processing Record 32 of Set 11 | isla aguada
# Processing Record 33 of Set 11 | jundiai
# Processing Record 34 of Set 11 | bowen
# Processing Record 35 of Set 11 | tazmalt
# Processing Record 36 of Set 11 | san carlos de bariloche
# Processing Record 37 of Set 11 | baie-comeau
# Processing Record 38 of Set 11 | miri
# Processing Record 39 of Set 11 | starkville
# Processing Record 40 of Set 11 | tabou
# Processing Record 41 of Set 11 | yungkang
# City not found. Skipping...
# Processing Record 42 of Set 11 | alcantara
# Processing Record 43 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 11 | waipawa
# Processing Record 45 of Set 11 | oyon
# Processing Record 46 of Set 11 | grand gaube
# Processing Record 47 of Set 11 | alyangula
# Processing Record 48 of Set 11 | taoudenni
# Processing Record 49 of Set 11 | sioux lookout
# Processing Record 50 of Set 11 | chumikan
# Processing Record 1 of Set 12 | hualmay
# Processing Record 2 of Set 12 | povenets
# Processing Record 3 of Set 12 | keetmanshoop
# Processing Record 4 of Set 12 | port lincoln
# Processing Record 5 of Set 12 | trinidad
# Processing Record 6 of Set 12 | hailey
# Processing Record 7 of Set 12 | shaki
# Processing Record 8 of Set 12 | hailar
# Processing Record 9 of Set 12 | villarrica
# Processing Record 10 of Set 12 | oussouye
# Processing Record 11 of Set 12 | birao
# Processing Record 12 of Set 12 | mayumba
# Processing Record 13 of Set 12 | najran
# Processing Record 14 of Set 12 | andarab
# City not found. Skipping...
# Processing Record 15 of Set 12 | lucenec
# Processing Record 16 of Set 12 | epinal
# Processing Record 17 of Set 12 | at-bashi
# Processing Record 18 of Set 12 | ignacio zaragoza
# Processing Record 19 of Set 12 | bandarbeyla
# Processing Record 20 of Set 12 | uvira
# Processing Record 21 of Set 12 | campbell river
# Processing Record 22 of Set 12 | divnomorskoye
# Processing Record 23 of Set 12 | bemidji
# Processing Record 24 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 25 of Set 12 | sao jose da coroa grande
# Processing Record 26 of Set 12 | independence
# Processing Record 27 of Set 12 | san angelo
# Processing Record 28 of Set 12 | svetlogorsk
# Processing Record 29 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 12 | daru
# Processing Record 31 of Set 12 | ust-tsilma
# Processing Record 32 of Set 12 | monrovia
# Processing Record 33 of Set 12 | plettenberg bay
# Processing Record 34 of Set 12 | korla
# Processing Record 35 of Set 12 | kulautuva
# Processing Record 36 of Set 12 | mwanza
# Processing Record 37 of Set 12 | martil
# Processing Record 38 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 12 | opunake
# Processing Record 40 of Set 12 | mizdah
# Processing Record 41 of Set 12 | kirakira
# Processing Record 42 of Set 12 | cayenne
# Processing Record 43 of Set 12 | sayyan
# Processing Record 44 of Set 12 | kaka
# Processing Record 45 of Set 12 | dawlatabad
# Processing Record 46 of Set 12 | tibagi
# Processing Record 47 of Set 12 | acari
# Processing Record 48 of Set 12 | kashary
# Processing Record 49 of Set 12 | burica
# City not found. Skipping...
# Processing Record 50 of Set 12 | tabulbah
# City not found. Skipping...
# Processing Record 1 of Set 13 | jieshi
# Processing Record 2 of Set 13 | gloggnitz
# Processing Record 3 of Set 13 | champerico
# Processing Record 4 of Set 13 | araouane
# Processing Record 5 of Set 13 | teguise
# Processing Record 6 of Set 13 | itaqui
# Processing Record 7 of Set 13 | nantucket
# Processing Record 8 of Set 13 | kucove
# Processing Record 9 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 13 | beringovskiy
# Processing Record 11 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 12 of Set 13 | gubkinskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 556

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hasaki  35.7333  140.8333     41.40        71          93
# 1  Guerrero Negro  27.9769 -114.0611     56.59        74           0
# 2      Jabinyanah  35.0350   10.9081     63.07        55          28
# 3     Juan Lacaze -34.4342  -57.4381     78.87        48          10
# 4        Victoria  22.2855  114.1577     69.21        68          70
# 5    Puerto Ayora  -0.7393  -90.3518     72.55        97          28
# 6          Marawi   7.9986  124.2928     66.94        91         100
# 7           Tahta  26.7693   31.5021     68.02        32          79
# 8         Samarai -10.6167  150.6667     81.46        80         100
# 9          Barrow  71.2906 -156.7887     -9.38        77         100
#
#    Wind Speed Country                 Date Current Description
# 0        6.40      JP  2023-01-07 12:13:21     overcast clouds
# 1        3.94      MX  2023-01-07 12:13:21           clear sky
# 2       14.12      TN  2023-01-07 12:13:22          light rain
# 3       16.64      UY  2023-01-07 12:13:22           clear sky
# 4        5.01      HK  2023-01-07 12:12:24       broken clouds
# 5        1.01      EC  2023-01-07 12:12:57    scattered clouds
# 6        1.16      PH  2023-01-07 12:13:23     overcast clouds
# 7       10.51      EG  2023-01-07 12:13:23       broken clouds
# 8        5.12      PG  2023-01-07 12:13:23     overcast clouds
# 9       16.11      US  2023-01-07 12:13:24                haze

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]

# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hasaki      JP  35.7333  140.8333     41.40        71
# 1    Guerrero Negro      MX  27.9769 -114.0611     56.59        74
# 2        Jabinyanah      TN  35.0350   10.9081     63.07        55
# 3       Juan Lacaze      UY -34.4342  -57.4381     78.87        48
# 4          Victoria      HK  22.2855  114.1577     69.21        68
# ..              ...     ...      ...       ...       ...       ...
# 551          Itaqui      BR -29.1253  -56.5531     87.71        28
# 552       Nantucket      US  41.2835  -70.0995     39.25        93
# 553          Kucove      AL  40.8003   19.9167     60.17        46
# 554    Beringovskiy      RU  63.0500  179.3167     -3.59        95
# 555      Gubkinskiy      RU  64.4340   76.5026    -37.28        88
#
#      Cloudiness  Wind Speed Current Description
# 0            93        6.40     overcast clouds
# 1             0        3.94           clear sky
# 2            28       14.12          light rain
# 3            10       16.64           clear sky
# 4            70        5.01       broken clouds
# ..          ...         ...                 ...
# 551           2       12.03           clear sky
# 552         100        5.75     overcast clouds
# 553           0        3.36           clear sky
# 554         100       13.09     overcast clouds
# 555          54       11.14       broken clouds
#
# [556 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
