# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
# YOUR CODE HERE
city_data_df = pd.read_csv("..//Weather_Database/WeatherPy_Database.csv")

# Display sample data
# YOUR CODE HERE
city_data_df.head()
# Out:
#    City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0          Hasaki      JP  35.7333  140.8333     41.40        71
# 1        1  Guerrero Negro      MX  27.9769 -114.0611     56.59        74
# 2        2      Jabinyanah      TN  35.0350   10.9081     63.07        55
# 3        3     Juan Lacaze      UY -34.4342  -57.4381     78.87        48
# 4        4        Victoria      HK  22.2855  114.1577     69.21        68
#
#    Cloudiness  Wind Speed Current Description
# 0          93        6.40     overcast clouds
# 1           0        3.94           clear sky
# 2          28       14.12          light rain
# 3          10       16.64           clear sky
# 4          70        5.01       broken clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
# YOUR CODE HERE
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
# YOUR CODE HERE
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
# Display sample data
# YOUR CODE HERE
preferred_cities_df.head(10)
# Out:
#     City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 3         3  Juan Lacaze      UY -34.4342  -57.4381     78.87        48
# 8         8      Samarai      PG -10.6167  150.6667     81.46        80
# 10       10       Faanui      PF -16.4833 -151.7500     79.95        71
# 12       12       Namibe      AO -15.1961   12.1522     78.39        61
# 13       13   Bredasdorp      ZA -34.5322   20.0403     75.56        53
# 15       15         Chuy      UY -33.6971  -53.4616     75.72        54
# 17       17      Catuday      PH  16.2923  119.8062     78.33        65
# 19       19    Bathsheba      BB  13.2167  -59.5167     81.21        74
# 22       22       Mackay      AU -21.1500  149.2000     76.68        76
# 24       24      Rikitea      PF -23.1203 -134.9692     77.94        73
#
#     Cloudiness  Wind Speed Current Description
# 3           10       16.64           clear sky
# 8          100        5.12     overcast clouds
# 10          10        1.88           clear sky
# 12          39       11.90    scattered clouds
# 13          26       17.11    scattered clouds
# 15           3       10.36           clear sky
# 17          15       14.67          few clouds
# 19          40       20.71    scattered clouds
# 22          33        9.35    scattered clouds
# 24          31       13.06    scattered clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
# YOUR CODE HERE
preferred_cities_df.count()

# Display sample data
# YOUR CODE HERE
# Out:
# City_ID                152
# City                   152
# Country                152
# Lat                    152
# Lng                    152
# Max Temp               152
# Humidity               152
# Cloudiness             152
# Wind Speed             152
# Current Description    152
# dtype: int64

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
# YOUR CODE HERE
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()

# %%
## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame
# Create a new column "Hotel Name".
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""
# Display sample data
# YOUR CODE HERE
hotel_df.head(10)
# Out:
#            City Country  Max Temp      Lat       Lng Hotel Name
# 3   Juan Lacaze      UY     78.87 -34.4342  -57.4381
# 8       Samarai      PG     81.46 -10.6167  150.6667
# 10       Faanui      PF     79.95 -16.4833 -151.7500
# 12       Namibe      AO     78.39 -15.1961   12.1522
# 13   Bredasdorp      ZA     75.56 -34.5322   20.0403
# 15         Chuy      UY     75.72 -33.6971  -53.4616
# 17      Catuday      PH     78.33  16.2923  119.8062
# 19    Bathsheba      BB     81.21  13.2167  -59.5167
# 22       Mackay      AU     76.68 -21.1500  149.2000
# 24      Rikitea      PF     77.94 -23.1203 -134.9692

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Juan Lacaze - nearest hotel: No hotel found
# Samarai - nearest hotel: No hotel found
# Faanui - nearest hotel: Oa Oa Lodge
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Bredasdorp - nearest hotel: Victoria Hotel
# Chuy - nearest hotel: Alerces
# Catuday - nearest hotel: Nina Anchors Inn
# Bathsheba - nearest hotel: Atlantis Hotel
# Mackay - nearest hotel: Mackay Oceanside Central Apartment Hotel
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Saint-Philippe - nearest hotel: Le Baril
# Kolokani - nearest hotel: Hôtel kolokani
# Hermanus - nearest hotel: Aloe guest house
# Atuona - nearest hotel: Pearl Resort
# Raga - nearest hotel: No hotel found
# Cape Town - nearest hotel: Townhouse Hotel
# Sagaing - nearest hotel: Top Royal Hotel
# Port-Gentil - nearest hotel: Tara-Mé
# Butaritari - nearest hotel: No hotel found
# Roebourne - nearest hotel: No hotel found
# Mar Del Plata - nearest hotel: Nuevo Ostende
# Karratha - nearest hotel: Karratha International Hotel
# Nioro - nearest hotel: No hotel found
# Port Elizabeth - nearest hotel: Waterford Hotel
# Vila Velha - nearest hotel: Hotel Prainha
# Sola - nearest hotel: No hotel found
# Qandala - nearest hotel: No hotel found
# Georgetown - nearest hotel: Page 63 hostel
# Poum - nearest hotel: No hotel found
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Caravelas - nearest hotel: Pousada dos Navegantes
# La Asuncion - nearest hotel: Hotel La Ciudad
# Saint-Pierre - nearest hotel: Tropic Hotel
# Pemangkat - nearest hotel: Hotel Kelapa Gading
# Santa Vitoria Do Palmar - nearest hotel: Hotel Brasil
# Le Port - nearest hotel: No hotel found
# Canutama - nearest hotel: No hotel found
# Bambous Virieux - nearest hotel: No hotel found
# Vaini - nearest hotel: Keleti International Resort
# Mitsamiouli - nearest hotel: Hotel le Paradis
# Bosaso - nearest hotel: Bosaso hotel
# Hithadhoo - nearest hotel: Pebbles Inn
# Baracoa - nearest hotel: Casa
# Mahebourg - nearest hotel: Grand Bel Air
# Broken Hill - nearest hotel: Ibis Styles
# Isabela - nearest hotel: No hotel found
# Kavieng - nearest hotel: Kavieng Hotel
# Belmonte - nearest hotel: No hotel found
# Alofi - nearest hotel: No hotel found
# Kabalo - nearest hotel: No hotel found
# Niamey - nearest hotel: Redidence Croix du Sud
# Namatanai - nearest hotel: Namatanai Hotel
# Carnarvon - nearest hotel: No hotel found
# Oistins - nearest hotel: The Abidah By Accra
# Quatre Cocos - nearest hotel: Horisun
# Kaoma - nearest hotel: Pumulo Pardway Lodge
# Kadhan - nearest hotel: No hotel found
# Moindou - nearest hotel: No hotel found
# Lekoni - nearest hotel: Le rdv des chasseurs
# Labuhan - nearest hotel: No hotel found
# Urucara - nearest hotel: No hotel found
# Wewak - nearest hotel: Village Inn
# Poso - nearest hotel: Nusantara
# Vanimo - nearest hotel: CBC Guesthouse
# Axim - nearest hotel: Axim Beach Hotel
# Port Keats - nearest hotel: No hotel found
# Kualakapuas - nearest hotel: Hotel Bayu
# Adre - nearest hotel: No hotel found
# Cumana - nearest hotel: Hotel Regina
# Weligama - nearest hotel: Basecamp
# Camocim - nearest hotel: Hotel Camocim
# Aquiraz - nearest hotel: Pousada tia Fabíola
# Loandjili - nearest hotel: Le Raphia Guest House
# Kathu - nearest hotel: Tinidee Hotel
# Bilma - nearest hotel: No hotel found
# Barra Do Corda - nearest hotel: Hotel Belcho
# Finschhafen - nearest hotel: No hotel found
# Buchanan - nearest hotel: Phillipmena's Guesthouse
# Luanda - nearest hotel: Hotel Forum
# Maues - nearest hotel: No hotel found
# Maine-Soroa - nearest hotel: Maïné-Soroa
# Maumere - nearest hotel: Bogor
# Marzuq - nearest hotel: No hotel found
# Simpang - nearest hotel: No hotel found
# Arroio Grande - nearest hotel: No hotel found
# Banjar - nearest hotel: Villa Banjar Beach
# Bengkulu - nearest hotel: Dena Hotel
# Honiara - nearest hotel: King Solomon Hotel
# Thinadhoo - nearest hotel: No hotel found
# Nhulunbuy - nearest hotel: No hotel found
# Manicore - nearest hotel: No hotel found
# Harper - nearest hotel: No hotel found
# Barentu - nearest hotel: No hotel found
# Salinopolis - nearest hotel: Hotel Salinópolis
# Sinnamary - nearest hotel: Hôtel du fleuve
# Hobyo - nearest hotel: No hotel found
# Touros - nearest hotel: Pousada Atlântico
# Boyolangu - nearest hotel: No hotel found
# Neiafu - nearest hotel: Port Wine Guest House
# Damortis - nearest hotel: No hotel found
# Marsabit - nearest hotel: Chicho Hotel
# Limulunga - nearest hotel: St. Lawrence Lodge
# Metro - nearest hotel: Hotel Nuban
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Padang - nearest hotel: losmen Surya
# Ifanadiana - nearest hotel: No hotel found
# Maracana - nearest hotel: Pousada & Restaurante Rola Papo
# Sumenep - nearest hotel: No hotel found
# Hoima - nearest hotel: hôtel
# San Juan - nearest hotel: Hotel San Francisco
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Taganak - nearest hotel: No hotel found
# Guanica - nearest hotel: Copamarina Beach Resort
# Cabedelo - nearest hotel: No hotel found
# Cidreira - nearest hotel: Hotel Castelo
# Grand-Santi - nearest hotel: No hotel found
# Meulaboh - nearest hotel: Hotel Meuligou
# Kananga - nearest hotel: Hôtel Résidence
# Villa Bruzual - nearest hotel: Hotel Turístico Sol de Arichuna
# Trat - nearest hotel: No hotel found
# Aden - nearest hotel: فندق قصر الجزيرة
# Alice Springs - nearest hotel: Aurora Alice Springs
# Saint-Leu - nearest hotel: Iloha Seaview Hôtel
# Rio Cuarto - nearest hotel: Marluc
# Souillac - nearest hotel: Hotel SkylineInn
# Kieta - nearest hotel: No hotel found
# Bintulu - nearest hotel: Bakun Inn
# Pandan Niog - nearest hotel: No hotel found
# Tautira - nearest hotel: No hotel found
# Umm Kaddadah - nearest hotel: No hotel found
# Vung Tau - nearest hotel: No hotel found
# Isla Aguada - nearest hotel: Puerto Sabalo Hotel
# Bowen - nearest hotel: Whitsunday Sands Resort
# Miri - nearest hotel: Kenyalang Suites Miri
# Tabou - nearest hotel: hôtel le rochet
# Alcantara - nearest hotel: Pousada La Maison du Baron
# Grand Gaube - nearest hotel: Coco Villa
# Alyangula - nearest hotel: No hotel found
# Trinidad - nearest hotel: Hotel Palace
# Villarrica - nearest hotel: No hotel found
# Oussouye - nearest hotel: Campement Alulum
# Mayumba - nearest hotel: Résidence Hôtelière Fabso
# Bandarbeyla - nearest hotel: No hotel found
# Uvira - nearest hotel: Batiment Kasangala
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Daru - nearest hotel: Kuki
# Monrovia - nearest hotel: Bella Casa Hotel
# Mwanza - nearest hotel: No hotel found
# Kirakira - nearest hotel: No hotel found
# Acari - nearest hotel: No hotel found
# Araouane - nearest hotel: No hotel found
# Itaqui - nearest hotel: Hotel Contursi
#             City Country  Max Temp      Lat       Lng              Hotel Name
# 3    Juan Lacaze      UY     78.87 -34.4342  -57.4381          No hotel found
# 8        Samarai      PG     81.46 -10.6167  150.6667          No hotel found
# 10        Faanui      PF     79.95 -16.4833 -151.7500             Oa Oa Lodge
# 12        Namibe      AO     78.39 -15.1961   12.1522  Hotel Chik Chik Namibe
# 13    Bredasdorp      ZA     75.56 -34.5322   20.0403          Victoria Hotel
# ..           ...     ...       ...      ...       ...                     ...
# 534       Mwanza      TZ     80.65  -2.5167   32.9000          No hotel found
# 538     Kirakira      SB     81.63 -10.4544  161.9205          No hotel found
# 544        Acari      PE     75.60 -15.4311  -74.6158          No hotel found
# 549     Araouane      ML     80.60  18.9048   -3.5265          No hotel found
# 551       Itaqui      BR     87.71 -29.1253  -56.5531          Hotel Contursi
#
# [152 rows x 6 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
# YOUR CODE HERE
clean_hotel_df = hotel_df[hotel_df["Hotel Name"].str.contains("No hotel found")==False]
# Display sample data
# YOUR CODE HERE
clean_hotel_df
# Out:
#                          City Country  Max Temp      Lat       Lng  \
# 10                     Faanui      PF     79.95 -16.4833 -151.7500
# 12                     Namibe      AO     78.39 -15.1961   12.1522
# 13                 Bredasdorp      ZA     75.56 -34.5322   20.0403
# 15                       Chuy      UY     75.72 -33.6971  -53.4616
# 17                    Catuday      PH     78.33  16.2923  119.8062
# ..                        ...     ...       ...      ...       ...
# 520                     Uvira      CD     81.01  -3.4067   29.1458
# 524  Sao Jose Da Coroa Grande      BR     83.57  -8.8978  -35.1478
# 528                      Daru      PG     77.14  -9.0763  143.2092
# 530                  Monrovia      LR     87.57   6.3005  -10.7969
# 551                    Itaqui      BR     87.71 -29.1253  -56.5531
#
#                  Hotel Name
# 10              Oa Oa Lodge
# 12   Hotel Chik Chik Namibe
# 13           Victoria Hotel
# 15                  Alerces
# 17         Nina Anchors Inn
# ..                      ...
# 520      Batiment Kasangala
# 524            Hotel do Sol
# 528                    Kuki
# 530        Bella Casa Hotel
# 551          Hotel Contursi
#
# [97 rows x 6 columns]

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
# YOUR CODE HERE
output_data_file = "WeatherPy_vacation.csv"
# Export the City_Data into a csv
# YOUR CODE HERE
clean_hotel_df.to_csv(output_data_file, index_label="City")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
# YOUR CODE HERE
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
# YOUR CODE HERE
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country)
